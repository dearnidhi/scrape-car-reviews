# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=cpo&makes%5B%5D=mercedes_benz&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
results = soup.find_all('div', {'class' : 'vehicle-card'})

# %%
#len(results)

# %%
# Name
# Mileage
# Dealer Name
# Rating
# Rating Count
# Price

# %%
results[0].find('h2').get_text()
# Out:
# '2022 Mercedes-Benz E-Class E 350'

# %%
results[0].find('div', {'class':'mileage'}).get_text()
# Out:
# '1,755 mi.'

# %%
results[0].find('div', {'class':'dealer-name'}).get_text().strip()
# Out:
# "Walter's Mercedes-Benz of Riverside"

# %%
results[0].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.9'

# %%
results[0].find('span', {'class':'sds-rating__link'}).get_text()
# Out:
# '(6,674 reviews)'

# %%
results[0].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$57,040'

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    # name
    try:
        name.append(result.find('h2').get_text()) 
    except:
        name.append('n/a')
    
    # mileage
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('n/a')
    
    # dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')
        
    # rating
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')
    
    # review_count
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')
    
    #price 
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                        Name     Mileage  \
# 0          2022 Mercedes-Benz E-Class E 350   1,755 mi.
# 1   2021 Mercedes-Benz Maybach S 580 4MATIC   4,058 mi.
# 2    2020 Mercedes-Benz GLS 450 Base 4MATIC  35,323 mi.
# 3        2021 Mercedes-Benz AMG GLE 53 Base   9,734 mi.
# 4        2022 Mercedes-Benz AMG G 63 4MATIC   2,591 mi.
# 5          2019 Mercedes-Benz S-Class S 560  14,773 mi.
# 6         2022 Mercedes-Benz GLS 450 4MATIC  20,195 mi.
# 7        2022 Mercedes-Benz AMG G 63 4MATIC   3,533 mi.
# 8        2022 Mercedes-Benz AMG G 63 4MATIC   8,192 mi.
# 9    2020 Mercedes-Benz GLE 350 Base 4MATIC  36,944 mi.
# 10       2023 Mercedes-Benz AMG GLE 53 Base   2,179 mi.
# 11  2019 Mercedes-Benz C-Class C 300 4MATIC  52,154 mi.
# 12          2022 Mercedes-Benz AMG GLE 63 S   2,848 mi.
# 13        2021 Mercedes-Benz GLS 450 4MATIC  32,376 mi.
# 14    2021 Mercedes-Benz GLE 450 AWD 4MATIC  16,862 mi.
# 15  2020 Mercedes-Benz S-Class S 560 4MATIC  12,870 mi.
# 16   2020 Mercedes-Benz GLS 450 Base 4MATIC  13,663 mi.
# 17         2020 Mercedes-Benz E-Class E 350  19,600 mi.
# 18  2021 Mercedes-Benz AMG E 53 Base 4MATIC   6,405 mi.
# 19  2020 Mercedes-Benz AMG E 53 Base 4MATIC   9,908 mi.
# 20  2021 Mercedes-Benz S-Class S 580 4MATIC   8,539 mi.
#
#                                           Dealer Name Rating     Review Count  \
# 18  2021 Mercedes-Benz AMG E 53 Base 4MATIC   6,405 mi.
# 19  2020 Mercedes-Benz AMG E 53 Base 4MATIC   9,908 mi.
# 20  2021 Mercedes-Benz S-Class S 580 4MATIC   8,539 mi.
#
#                                           Dealer Name Rating Review Count  \
# 0                 Walter's Mercedes-Benz of Riverside    4.9       6,674
# 1            Fletcher Jones Motorcars - Newport Beach    4.9       5,342
# 2                             Mercedes-Benz of Edison    5.0       3,886
# 3                       Mercedes-Benz of West Houston    4.7          73
# 4                              Benzel-Busch Motor Car    4.5       5,215
# 5            Fletcher Jones Motorcars - Newport Beach    4.9       5,342
# 6                             Mercedes-Benz of Edison    5.0       3,886
# 7                        Mercedes-Benz of Kansas City    4.7         762
# 8                          Mercedes-Benz of Asheville    4.6         257
# 9                                     Autobahn Motors    4.8         995
# 10                   Mercedes-Benz of Hoffman Estates    4.6       1,180
# 11                          Mercedes-Benz of Westmont    4.6       1,088
# 12                          Mercedes-Benz of Temecula    4.0       1,397
# 13                            Mercedes-Benz of Natick    4.9       2,487
# 14           Fletcher Jones Motorcars - Newport Beach    4.9       5,342
# 15                   Mercedes-Benz of Hoffman Estates    4.6       1,180
# 16                   Mercedes-Benz of Hoffman Estates    4.6       1,180
# 17                                   House of Imports    4.7       1,729
# 18  Mercedes-Benz of San Francisco / Smart Center ...    n/a          62
# 19                        Mercedes-Benz of Shrewsbury    4.6         200
# 20                                   House of Imports    4.7       1,729
#
#        Price
# 0    $57,040
# 1   $169,890
# 2    $68,510
# 3    $83,996
# 4   $211,923
# 5    $67,891
# 6    $82,495
# 7   $233,978
# 8   $219,992
# 9    $42,996
# 10   $99,999
# 11   $28,995
# 12  $114,993
# 13   $65,998
# 14   $67,892
# 15   $92,999
# 16   $72,999
# 17   $38,933
# 18   $69,987
# 19   $82,295
# 20   $93,990

# %%
#output in excel
car_dealer.to_excel('car_dealer_single_pages.xlsx', index=False)

# %%
#pagination
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range (1,11):
    
    # website in variable
    website = 'https://www.cars.com/shopping/results/?page='+ str(i) +'&page_size=20&dealer_id=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=20&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip=' 
    
    # request to website
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # results
    results = soup.find_all('div', {'class' : 'vehicle-card'})
    
    # loop through results
    for result in results:
    
        # name
        try:
            name.append(result.find('h2').get_text()) 
        except:
            name.append('n/a')

        # mileage
        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('n/a')

        # dealer_name
        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

        # rating
        try:
            rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
        except:
            rating.append('n/a')

        # review_count
        try:
            review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
        except:
            review_count.append('n/a')

        #price 
        try:
            price.append(result.find('span', {'class':'primary-price'}).get_text())
        except:
            price.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                         Name     Mileage  \
# 0           2022 Mercedes-Benz E-Class E 350   1,755 mi.
# 1    2021 Mercedes-Benz Maybach S 580 4MATIC   4,058 mi.
# 2           2019 Mercedes-Benz S-Class S 560  14,773 mi.
# 3         2021 Mercedes-Benz AMG GLE 53 Base   9,734 mi.
# 4         2022 Mercedes-Benz AMG G 63 4MATIC   8,192 mi.
# ..                                       ...         ...
# 202    2020 Mercedes-Benz GLE 450 AWD 4MATIC  41,816 mi.
# 203       2022 Mercedes-Benz AMG GLE 53 Base  18,184 mi.
# 204         2019 Mercedes-Benz S-Class S 560  24,056 mi.
# 205       2022 Mercedes-Benz AMG GLE 53 Base   8,558 mi.
# 206       2021 Mercedes-Benz GLS 580 GLS 580  21,912 mi.
#
#                                   Dealer Name Rating     Review Count  \
# 0         Walter's Mercedes-Benz of Riverside    4.9  (6,674 reviews)
# 1    Fletcher Jones Motorcars - Newport Beach    4.9  (5,342 reviews)
# 2    Fletcher Jones Motorcars - Newport Beach    4.9  (5,342 reviews)
# 3               Mercedes-Benz of West Houston    4.7     (73 reviews)
# 4                  Mercedes-Benz of Asheville    4.6    (257 reviews)
# ..                                        ...    ...              ...
# 202            Mercedes-Benz of North Olmsted    4.7  (1,529 reviews)
# 203       Fletcher Jones Motorcars of Fremont    4.7  (1,218 reviews)
# 204                          House of Imports    4.7  (1,729 reviews)
# 205             Mercedes-Benz of Walnut Creek    4.5  (1,011 reviews)
# 206                 Mercedes-Benz of Lynnwood    4.4    (130 reviews)
#
#         Price
# 0     $57,040
# 1    $169,890
# 2     $67,891
# 3     $83,996
# 4    $219,992
# ..        ...
# 202   $55,495
# 203   $86,984
# 204   $85,391
# 205   $87,486
# 206   $94,250
#
# [207 rows x 6 columns]

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                         Name     Mileage  \
# 0           2022 Mercedes-Benz E-Class E 350   1,755 mi.
# 1    2021 Mercedes-Benz Maybach S 580 4MATIC   4,058 mi.
# 2           2019 Mercedes-Benz S-Class S 560  14,773 mi.
# 3         2021 Mercedes-Benz AMG GLE 53 Base   9,734 mi.
# 4         2022 Mercedes-Benz AMG G 63 4MATIC   8,192 mi.
# ..                                       ...         ...
# 202    2020 Mercedes-Benz GLE 450 AWD 4MATIC  41,816 mi.
# 203       2022 Mercedes-Benz AMG GLE 53 Base  18,184 mi.
# 204         2019 Mercedes-Benz S-Class S 560  24,056 mi.
# 205       2022 Mercedes-Benz AMG GLE 53 Base   8,558 mi.
# 206       2021 Mercedes-Benz GLS 580 GLS 580  21,912 mi.
#
#                                   Dealer Name Rating Review Count     Price
# 0         Walter's Mercedes-Benz of Riverside    4.9       6,674    $57,040
# 1    Fletcher Jones Motorcars - Newport Beach    4.9       5,342   $169,890
# 2    Fletcher Jones Motorcars - Newport Beach    4.9       5,342    $67,891
# 3               Mercedes-Benz of West Houston    4.7          73    $83,996
# 4                  Mercedes-Benz of Asheville    4.6         257   $219,992
# ..                                        ...    ...          ...       ...
# 202            Mercedes-Benz of North Olmsted    4.7       1,529    $55,495
# 203       Fletcher Jones Motorcars of Fremont    4.7       1,218    $86,984
# 204                          House of Imports    4.7       1,729    $85,391
# 205             Mercedes-Benz of Walnut Creek    4.5       1,011    $87,486
# 206                 Mercedes-Benz of Lynnwood    4.4         130    $94,250
#
# [207 rows x 6 columns]

# %%
car_dealer.to_csv('car_deal.csv', index=False)
